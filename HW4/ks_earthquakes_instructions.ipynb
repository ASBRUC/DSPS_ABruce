# %% [markdown]
# <a href="https://colab.research.google.com/github/ASBRUC/DSPS_ABruce/blob/main/HW4/ks_earthquakes_instructions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Created by FedericaBBianco @fedhere for DSPS/MLNPS
# # Kolmogorov Smirnoff test, application to earthquake data

# %% [markdown]
# I, Alex Bruce worked on this assignment with Zoe Beris. <br>
# We collabarated together to find efficent ways to sort and modify the data. Zoe helped with displaying clear and readable plots.

# %%
#all the imports I needed
import pandas as pd
import pylab as pl
import scipy as sp
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
#%pylab inline
#pl.style.use("https://raw.githubusercontent.com/fedhere/DSPS/master/fbb.mplstyle")

# %% [markdown]
# This homework asks you to reproduce the work in [Corral 2018](https://arxiv.org/pdf/0910.0055.pdf) which is well described, but not "reproducible".
# Corral 2018 uses a K-S test to show that at different magnitude scales the time gaps between earthquakes follows the same distribution. If true, this indicates that there is a consistent scaling law.
#
# The argument is a little convoluted, but it is a somewhat innovative use of the test. Corall compares the time gap between earthquakes  greater than a certain magnitude threshold with the time gaps between earthquakes above a different threshold, and finds no differences.
#
# Remind yourself exactly what the K-S test is about :
#
#     1 What is the test's Null Hypothsis that the K-S test tests?

# %% [markdown]
# The null hypothesis is that both data sets come from the same distribution.

# %% [markdown]
#     2 What is the "statistic" or "pivotal quantity" that the test uses?

# %% [markdown]
# The maximum difference or dkl is the statistic this K-S test test uses.

# %% [markdown]
#     3 What does the probability distribution of this statistic depend on?

# %% [markdown]
# The equation for dkl is: dkl = max|Pk(x)-Pl(x)|
# The Pk(x) value represents the fraction of data points in the k data set that are less than the value x (same with data set l Pl(x)). So, this value will be the max of the substracted fractions across all x values.

# %% [markdown]
# # PART I:  Data Retrival

# %% [markdown]
# The first reason why the paper is not techincally _reproducible_ is that, while a link is provided to retrieve the data, the link is dead. This happens often. Services like [Zenodo](https://zenodo.org/) or journals that serve data provide some insurance against this but unfortunately the standards are not strict.

# %% [markdown]
# You can retrieve the data yourself from [this website](http://service.scedc.caltech.edu/eq-catalogs/poly.php). Think about what setting up data like this means for reproducibility. Did the author comply to reproducibility standards?__ Make sure the number of entries in your final dataset is similar to that of the authors. I got 70798, instead of 77000. 10% off, which I deem close enough. You should get something similar. Use the map in the paper to determine the region of interest. Call the file earthquakes_\<firstinitialLastname\>.csv and upload it to your github repository. Read it your file, instead of mine as instructed below. If you are getting weird results compare to what I got, go back and check how the files differ.

# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ## read in data

# %% [markdown]
# I saved the data in a file called "earthquakes.csv", where ```csv``` stands for "comma separated file". [This file format](https://www.howtogeek.com/348960/what-is-a-csv-file-and-how-do-i-open-it/) requires different entries in a row to be separated by commas alone (no space) and for commas to be used in quote if they are not intended to separate entries.
#
# ```
# a,b,c
# d,e,f
# g,"h,2",i
# ```
# The data is uploaded on the  github homework repository but to read it in you will need to get the link to the *raw file*: the link to the file earthquakes.csv which is in my GitHub repository https://github.com/fedhere/DSPS_FBianco/tree/main/data takes you to an ```html``` page that includes the content of the file, but you want to isolate the content of the file itself: the _raw file_. Pay attention to this: from the next time I will not give you the exact link, I will just point you to the file and you will have to find the link to the raw data from there. (remember to use the "raw" link)
#
# The data can be read effectively using the _pandas_ python package as ```pandas.read_csv(<file name or URL>)```.
#
# However, I did not format the data correctly, according to the csv extension requirement. This happens all the time. Look at the file and use the pandas documentation to figure out how to read it with ```pd.read_csv()```

# %%
eqdata = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv",
            sep=r"\s+")

# %% [markdown]
# running the following lines of code should give you the same result as mine if you used the file I provided (467 students), and qualitatively  similar if you are using your own data (667 students)

# %%
#note: the number of columns may be different depending on how you read the data in. The number of ROWs MUST be the same
eqdata.shape #also note: in class we used a different name for the dataframe
# Out:
# (70798, 13)

# %%
eqdata.head()
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M     LAT      LON  DEPTH  Q   EVID  \
# 0  1984/01/01  01:30:57.52  eq  l  2.02  c  33.246 -116.433    1.6  C  28255
# 1  1984/01/01  05:31:34.16  eq  l  2.12  c  32.945 -116.295    5.4  C  28259
# 2  1984/01/01  06:59:05.14  eq  l  2.43  c  33.343 -117.628    5.6  C  28260
# 3  1984/01/01  11:10:25.29  eq  l  2.07  c  33.668 -116.780   13.8  C  28270
# 4  1984/01/01  19:38:19.79  eq  l  2.13  c  33.963 -116.290    2.7  C  28553
#
#    NPH  NGRM
# 0   13    17
# 1   18    42
# 2   13    30
# 3   19    40
# 4   40    49

# %%
eqdata.describe()
# Out:
#                 MAG           LAT          LON         DEPTH          EVID  \
# count  70798.000000  70798.000000  70798.00000  70798.000000  7.079800e+04
# mean       2.417826     33.977749   -116.88145      5.707677  3.699163e+06
# std        0.407683      1.156586      1.07667      3.842620  3.495378e+06
# min        2.000000     30.094830   -121.76000      0.000000  2.825500e+04
# 25%        2.120000     33.061000   -117.69200      3.100000  7.380962e+05
# 50%        2.300000     34.056750   -116.59000      5.300000  3.049477e+06
# 75%        2.590000     34.591000   -116.25100      6.900000  3.325926e+06
# max        7.100000     37.985500   -113.71900     29.300000  3.736673e+07
#
#                 NPH          NGRM
# count  70798.000000  70798.000000
# mean      30.424376    175.725049
# std       22.374143    226.196774
# min        0.000000      0.000000
# 25%       15.000000     59.000000
# 50%       24.000000    111.000000
# 75%       39.000000    211.000000
# max      406.000000   3815.000000

# %% [markdown]
# now that you have a dataframe object you can use methods of the object to modify it. Use the method ```eqdata.rename``` to change the names of the 3 columns that are the only three relevant to us: _date, time, magnitude_

# %% [markdown]
# ## prepare date-time column

# %%
eqdata = eqdata[['#YYY/MM/DD', 'HH:mm:SS.ss','MAG']]
eqdata = eqdata.rename({"#YYY/MM/DD": "Date","HH:mm:SS.ss": "Time","MAG": "Magnitude"}, axis = 1)

# %%
eqdata.head()
# Out:
#          Date         Time  Magnitude
# 0  1984/01/01  01:30:57.52       2.02
# 1  1984/01/01  05:31:34.16       2.12
# 2  1984/01/01  06:59:05.14       2.43
# 3  1984/01/01  11:10:25.29       2.07
# 4  1984/01/01  19:38:19.79       2.13

# %%
eqdata.describe()
# Out:
#           Magnitude
# count  70798.000000
# mean       2.417826
# std        0.407683
# min        2.000000
# 25%        2.120000
# 50%        2.300000
# 75%        2.590000
# max        7.100000

# %% [markdown]
# Now you want to combine the columns containing date and time and convert them to a "datetime" kind of data object.

# %% [markdown]
# What data type are the _time_ and _date_ columns right now? What type you want them to be to conver them to datetime with ```pd.datetime()```? type 'O' means object, typically a string.

# %%
#eqdata.time.dtype, #eqdata.date.dtype

# %% [markdown]
# to do this conversion I
#
#    1. joined date and time into a single string for each row with a ["list comprehension"](https://www.pythonforbeginners.com/basics/list-comprehensions-in-python) (essentially a for loop but more efficient and compact). You do not have to do it with a list comprehension, you can use just a for loop.
#
#    2. used pd.datetime() to convert the resulting new dataframe column into a dataframe column containing _datetime_ objects (see lab)
#
#    3. but this did not work because of the formatting of some dates, so I had to go back and fix 5 entries. (you are on your own to figure out this one)

# %%
eqdata["newdates"] = eqdata["Date"].map(pd.to_datetime)

for i in eqdata.index:
  if eqdata.loc[i, "Time"].endswith('60.00'):
    eqdata.loc[i, "Time"] = eqdata.loc[i, "Time"][:6] + "59.99"

eqdata["datetime"] = eqdata["Date"] + " " + eqdata["Time"]
eqdata["datetime"] = eqdata["datetime"].map(pd.to_datetime)
eqdata = eqdata.drop(["Date", "Time", "newdates"], axis = 1)

# %%
eqdata.head()
# Out:
#    Magnitude                datetime
# 0       2.02 1984-01-01 01:30:57.520
# 1       2.12 1984-01-01 05:31:34.160
# 2       2.43 1984-01-01 06:59:05.140
# 3       2.07 1984-01-01 11:10:25.290
# 4       2.13 1984-01-01 19:38:19.790

# %% [markdown]
# ## select valuable data
# Starting here is stuff we did not do together in class but is part of the homework due on 9/17

# %% [markdown]
# Following the description in Section 2  of Corral 2018 I removed all data that did not belong to a "stationary" period. Third paragraph section 2 of Corral 2018. You can see the cell of code I used to do this [here](https://github.com/fedhere/DSPS_FBianco/blob/master/HW3/Corral2018_selectStationary.py) at no points cost, cause it was a bit tricky, but I encourage you to try and do it yourself. If you can do it in fewer lines than I did its automatically +5 points (just turning the loop into a list comprehension does not count. That is an obvious way to decrease the number of lines of code; I did not do it simply to enhance readability.)

# %%
# create empty container
ss = []

# loop through all year pairs as year and fraction of year
for t in [(1984, 1986.5),
          (1990.3, 1992.1),
          (1994.6, 1995.6),
          (1996.1,1996.5),
          (1997,1997.6),
          (1997.75,1998.15),
          (1998.25,1999.35),
          (2000.55,2000.8),
          (2000.9 ,2001.25),
          (2001.6 ,2002),
          (2002.5 ,2003)]:

    # for each pair I convert the year to datetime (easy)
    # then I convert the fraction of year and convert it to days and convert that to a delta-time
    # finally I add that deltatime to the year datetime.
    ss.append((pd.to_datetime(int(t[0]), format="%Y")
        + pd.Timedelta('%.f days'%((t[0] - int(t[0])) * 365.25)),
               pd.to_datetime(int(t[1]), format="%Y")
        + pd.Timedelta('%.f days'%((t[1] - int(t[1])) * 365.25))))


############
print ("the {} timestamp pairs that are the boundaries of good data periods are:".format(len(ss)))


############

# data between start and end of first time period
gooddates = (((eqdata.datetime >= ss[0][0]) * (eqdata.datetime <= ss[0][1])) +\
        # data between start and end of second time period
        ((eqdata.datetime >=ss [1][0]) * (eqdata.datetime <= ss[1][1])) +\
        ((eqdata.datetime >=ss [2][0]) * (eqdata.datetime <= ss[2][1])) +\
        ((eqdata.datetime >=ss [3][0]) * (eqdata.datetime <= ss[3][1])) +\
        ((eqdata.datetime >=ss [4][0]) * (eqdata.datetime <= ss[4][1])) +\
        ((eqdata.datetime >=ss [5][0]) * (eqdata.datetime <= ss[5][1])) +\
        ((eqdata.datetime >=ss [6][0]) * (eqdata.datetime <= ss[6][1])) +\
        ((eqdata.datetime >=ss [7][0]) * (eqdata.datetime <= ss[7][1])) +\
        ((eqdata.datetime >=ss [8][0]) * (eqdata.datetime <= ss[8][1])) +\
        ((eqdata.datetime >=ss [9][0]) * (eqdata.datetime <= ss[9][1])) +\
        # data between start and end of last time period
        ((eqdata.datetime >=ss [10][0]) * (eqdata.datetime <= ss[10][1])\
        ).values)
gooddates
# Out:
# the 11 timestamp pairs that are the boundaries of good data periods are:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 70793    True
# 70794    True
# 70795    True
# 70796    True
# 70797    True
# Name: datetime, Length: 70798, dtype: bool

# %%
eqdata
# Out:
#        Magnitude                datetime
# 0           2.02 1984-01-01 01:30:57.520
# 1           2.12 1984-01-01 05:31:34.160
# 2           2.43 1984-01-01 06:59:05.140
# 3           2.07 1984-01-01 11:10:25.290
# 4           2.13 1984-01-01 19:38:19.790
# ...          ...                     ...
# 70793       2.21 2002-12-29 19:37:24.560
# 70794       2.02 2002-12-29 20:17:33.400
# 70795       2.07 2002-12-29 20:21:28.730
# 70796       2.31 2002-12-30 21:51:52.550
# 70797       2.05 2002-12-30 23:38:49.790
#
# [70798 rows x 2 columns]

# %%
#print ("the {} timestamp pairs that are the boundaries of good data periods are:".format(len(ss)))

# %% [markdown]
# The following cell of code shows you the array of bool values (True/False) which I create to use as an index to the input array: when used as an index, a technique called "broadcasting" in python, will select only elements of the original array where the index array value is True. something like
# Try:

# %%
a = np.array([0, 1, 2])
a, a[[True, False, True]]
# Out:
# (array([0, 1, 2]), array([0, 2]))

# %% [markdown]
# For each of the 11 valid periods I create a condition
# ``` datetime >= period_start AND datetime <= period_end ``` where AND is a product of booleans: True * False = False.
#
# I want to take all chinks of data that satisfy this condition for any of the 11 chunks of time so that is a logical OR operator, or a sum of Booleans: True + False = True
#
# This is because ```True``` really corresponds to "not 0" and False to "0". So ```"not 0" * 0 = 0``` and ```"not 0" + 0 = not 0```

# %%
#

# %%
print ("there are {} earthquakes falling in the selected stationary periods".
       format(gooddates.sum()))
# Out:
# there are 18852 earthquakes falling in the selected stationary periods

# %%
# your code here: broadcasting to create a dataframe with the good dates only
#finding all the indexes of the rows that need to be removed
removeCol = [];
for i in gooddates.index:
  if gooddates[i] == False:
    removeCol.append(i);
#print(removeCol);

eqGoodData = eqdata.drop(removeCol)

# %%
eqGoodData.shape
# Out:
# (18852, 2)

# %%
eqGoodData.head()
# Out:
#    Magnitude                datetime
# 0       2.02 1984-01-01 01:30:57.520
# 1       2.12 1984-01-01 05:31:34.160
# 2       2.43 1984-01-01 06:59:05.140
# 3       2.07 1984-01-01 11:10:25.290
# 4       2.13 1984-01-01 19:38:19.790

# %% [markdown]
# Now what you really want is the _time interval between earthquakes_ for all events greater than some magnitude m, while all you have are the date and time of the events
#
# You can remove earthquakes smaller than magnitude 2 by, again, broadcasting. How would that look like?

# %%
for i in eqGoodData.index:
  if eqGoodData.loc[i, "Magnitude"] < 2:
    print("removed")
    eqGoodData = eqGoodData.drop(i, inplace = True)
#Nothing will print

# %%
eqGoodData.shape #look like for my data it was not needed! that is because I chose M>2 when when I downloaded the data
# Out:
# (18852, 2)

# %% [markdown]
# You can get the time between consecutive earthquakes with the method ```diff()``` of numpy arrays (as done in class).

# %%
eqGoodData["TimeDiff"] = eqGoodData["datetime"].diff()

# %%
eqGoodData.shape
# Out:
# (18852, 3)

# %%
eqGoodData.head()
# Out:
#    Magnitude                datetime               TimeDiff
# 0       2.02 1984-01-01 01:30:57.520                    NaT
# 1       2.12 1984-01-01 05:31:34.160 0 days 04:00:36.640000
# 2       2.43 1984-01-01 06:59:05.140 0 days 01:27:30.980000
# 3       2.07 1984-01-01 11:10:25.290 0 days 04:11:20.150000
# 4       2.13 1984-01-01 19:38:19.790 0 days 08:27:54.500000

# %%
eqGoodData.describe()
# Out:
#           Magnitude                       datetime                    TimeDiff
# count  18852.000000                          18852                       18851
# mean       2.399488  1992-11-23 17:12:55.962325376   0 days 08:50:03.239736353
# min        2.000000     1984-01-01 01:30:57.520000      0 days 00:00:00.170000
# 25%        2.110000     1985-10-23 18:38:51.520000      0 days 00:45:37.220000
# 50%        2.290000     1994-08-31 19:17:33.060000      0 days 02:29:07.620000
# 75%        2.570000     1998-05-07 05:13:29.890000      0 days 05:55:39.720000
# max        5.800000     2002-12-30 23:38:49.790000   1388 days 11:06:10.750000
# std        0.392436                            NaN  12 days 18:39:14.935603512

# %% [markdown]
# Note that the first entry will be NaT which is Not a Time (corresponding to nan for numerical variables) or maybe a negative number (depends on your exact operations above). You should remove it

# %%
eqGoodData.drop([0], inplace = True)

# %%
eqGoodData.head()
# Out:
#    Magnitude                datetime               TimeDiff
# 1       2.12 1984-01-01 05:31:34.160 0 days 04:00:36.640000
# 2       2.43 1984-01-01 06:59:05.140 0 days 01:27:30.980000
# 3       2.07 1984-01-01 11:10:25.290 0 days 04:11:20.150000
# 4       2.13 1984-01-01 19:38:19.790 0 days 08:27:54.500000
# 5       2.13 1984-01-01 19:39:19.670 0 days 00:00:59.880000

# %% [markdown]
# # data exploration
# At this point you should wonder if this is the final dataset that you want to use and if anything is weird or suspicious about it. Visualize the distribution. A good way to visualize distributions is a histogram which you can prodice with pl.hist() or as a method of your dataframe series as ```df[SeriesName].plot(kind="hist")```. Produce a plot like the one below (label the axis! and describe it with a caption!). To get the logarithmic y axis you can se ```logy=True```, for example. in your ```df[SeriesName].plot``` call.

# %%
#eqGoodData["TimeDiff"][1].total_seconds()
for i in eqGoodData.index:
  eqGoodData.loc[i, "TimeDiffNSec"] = eqGoodData.loc[i, "TimeDiff"].total_seconds() * 10**9;

eqGoodData
# Out:
#        Magnitude                datetime               TimeDiff  TimeDiffNSec
# 1           2.12 1984-01-01 05:31:34.160 0 days 04:00:36.640000  1.443664e+13
# 2           2.43 1984-01-01 06:59:05.140 0 days 01:27:30.980000  5.250980e+12
# 3           2.07 1984-01-01 11:10:25.290 0 days 04:11:20.150000  1.508015e+13
# 4           2.13 1984-01-01 19:38:19.790 0 days 08:27:54.500000  3.047450e+13
# 5           2.13 1984-01-01 19:39:19.670 0 days 00:00:59.880000  5.988000e+10
# ...          ...                     ...                    ...           ...
# 70793       2.21 2002-12-29 19:37:24.560 0 days 00:00:30.140000  3.014000e+10
# 70794       2.02 2002-12-29 20:17:33.400 0 days 00:40:08.840000  2.408840e+12
# 70795       2.07 2002-12-29 20:21:28.730 0 days 00:03:55.330000  2.353300e+11
# 70796       2.31 2002-12-30 21:51:52.550 1 days 01:30:23.820000  9.182382e+13
# 70797       2.05 2002-12-30 23:38:49.790 0 days 01:46:57.240000  6.417240e+12
#
# [18851 rows x 4 columns]

# %%
#eqGoodData["TimeDiffNSec"].plot(kind = "hist", logy = True)

fig, ax = plt.subplots(figsize = (6,6), dpi = 100)
plt.hist(eqGoodData["TimeDiffNSec"], bins = 10)
plt.xlabel("Time between earthquakes (ns)")
ax.set_yscale('log')
plt.ylabel("Number of Earthquakes")
plt.title("Distribution of Time Differences in Earthquakes")
fig.text(0.5, -0.15, "This figure shows the distribution of the differences in the earthquakes with the number of Earthquakes. This distribution shows that there are significant gaps in time between earthquakes in the data. These large gaps in time are artifical leading to false outliers.", ha = "center", wrap = True)
# Out:
# Text(0.5, -0.15, 'This figure shows the distribution of the differences in the earthquakes with the number of Earthquakes. This distribution shows that there are significant gaps in time between earthquakes in the data. These large gaps in time are artifical leading to false outliers.')

# %% [markdown]
# The thing that worries me is that by removing some sections of the data to use only stationary periods we created some artificially large gaps: gaps of order ~month. How many nanoseconds in a month? remove all gaps that are larger than about a month and see how the distribution looks (make another histogram).

# %%
#How many seconds in a month
MonthNSec = 2.628 * 10 **15;
for i in eqGoodData.index:
  if eqGoodData.loc[i, "TimeDiffNSec"] > MonthNSec:
    eqGoodData = eqGoodData.drop(i)

#eqGoodData["TimeDiffNSec"].plot(kind = "hist", logy = True);

fig, ax = plt.subplots(figsize = (6,6), dpi = 100)
plt.hist(eqGoodData["TimeDiffNSec"], bins = 10)
plt.xlabel("Time between earthquakes (ns)")
ax.set_yscale('log')
plt.ylabel("Number of Earthquakes")
plt.title("Distribution of Time Differences in Earthquakes")
fig.text(0.5, -0.15, "This figure shows the distribution of the differences in the earthquakes with the number of Earthquakes after getting rid of time differences more than a month. This distribution shows that there is no longer gaps in the time differences. Now most of the data has very small time differences, shown from the logy scale.", ha = "center", wrap = True)
# Out:
# Text(0.5, -0.15, 'This figure shows the distribution of the differences in the earthquakes with the number of Earthquakes after getting rid of time differences more than a month. This distribution shows that there is no longer gaps in the time differences. Now most of the data has very small time differences, shown from the logy scale.')

# %% [markdown]
# # PART II - data analysis

# %% [markdown]
# ### important: the paper does not do it but I want you to formally choose a threshold before you do this test. Choose a p-value (=$\alpha$ thresold: call your variable ```alpha```) of 3-$\sigma$.

# %%
alpha = 0.0003

# %% [markdown]
# Follow the instructions (algorithm) in **Section 3 paragraph 3** and compare your results with the results in table 1 with a threshold  of = 0.01 and 0.001
#
# Do it for all 5 magnitude thresholds as indicated in the paper (and in Table 1).
#
# Note that the x axis in plot Fig 1 is in _log space_. Use ```np.log10()``` to take the logarithm of the time gaps.
#
# The pseudocode for the algorithm is [here](https://github.com/fedhere/DSPS_FBianco/blob/master/HW3/Corral2018pseudocodeKStest.md).

# %% [markdown]
# Reproduce the paper Fig 1 and Table 1. In the Table report the size of each dataset after cleaning the value of the statistic and the p-value, as done in Corral 2018. Use the scipy function for the 2 sample KS test. (resources [here](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=70pYkR9LiOV0) to learn about the table syntax in markdown)

# %%
threshold = [0.01, 0.001]
mk_vals = [2.0, 2.5, 3.0, 3.5, 4.0]

for t in threshold: #goes through m = 0.01 and m = 0.001:
  for mk in mk_vals:
    #plt.figure(5,5);
    x_mk = eqGoodData.loc[eqGoodData["Magnitude"] >= mk, "TimeDiffNSec"]
    for i in [1,2]:
      rk = 1 / x_mk.mean()
      x_mk = x_mk.loc[x_mk * rk > t] #broadcasting
      x_mk = x_mk * rk
      x_mk = np.log10(x_mk)
      for ml in mk_vals: #calculating again for ml comparison
          if(mk < ml):
            x_ml = eqGoodData.loc[eqGoodData["Magnitude"] >= ml, "TimeDiffNSec"]
            for i in [1,2]:
              Rl = 1 / x_ml.mean()
              x_ml = x_ml.loc[x_ml * Rl > t]
              x_ml = x_ml * Rl
              x_ml = np.log10(x_ml)
            print(mk, ml, t) #normalize then take a log10
            print(sp.stats.ks_2samp(x_mk, x_ml)) #need to divide by the mean to normalize, the data will lead the data in a direction
            bins = np.linspace(-3,2,51)
            plt.hist(x_mk, bins = bins, cumulative = True, density = True, histtype = "step", label = f"mk >= {mk}, thresh={t}")
#density = true normalizes for us, should NOT need it.
#make histogram, then statistics

#for mk in mk_vals:
  #for ml in mk_vals:
#ml value is horizontal on the table
#mx value is vertical on the table
# Out:
# 2.0 2.5 0.01
# KstestResult(statistic=np.float64(0.3254896986953813), pvalue=np.float64(2.9555760720375555e-275), statistic_location=np.float64(-0.017683399624345796), statistic_sign=np.int8(1))
# 2.0 3.0 0.01
# KstestResult(statistic=np.float64(0.34078023262285045), pvalue=np.float64(6.017524396933573e-87), statistic_location=np.float64(0.0913202072738499), statistic_sign=np.int8(1))
# 2.0 3.5 0.01
# KstestResult(statistic=np.float64(0.31228990558366276), pvalue=np.float64(2.2535508068644614e-23), statistic_location=np.float64(0.019392309349282565), statistic_sign=np.int8(1))
# 2.0 4.0 0.01
# KstestResult(statistic=np.float64(0.3559817665777931), pvalue=np.float64(3.080058869952366e-09), statistic_location=np.float64(0.018648474468873133), statistic_sign=np.int8(1))
# 2.0 2.5 0.01
# KstestResult(statistic=np.float64(0.014128327674713115), pvalue=np.float64(0.6556575948109558), statistic_location=np.float64(-0.25804681735463497), statistic_sign=np.int8(-1))
# 2.0 3.0 0.01
# KstestResult(statistic=np.float64(0.03329668991062881), pvalue=np.float64(0.3211381337460708), statistic_location=np.float64(-0.25418016497593615), statistic_sign=np.int8(-1))
# 2.0 3.5 0.01
# KstestResult(statistic=np.float64(0.057141855327902336), pvalue=np.float64(0.34613412367636), statistic_location=np.float64(0.16457710595084676), statistic_sign=np.int8(-1))
# 2.0 4.0 0.01
# KstestResult(statistic=np.float64(0.11387168474090947), pvalue=np.float64(0.2577303852981605), statistic_location=np.float64(0.2616442236951069), statistic_sign=np.int8(-1))
# 2.5 3.0 0.01
# KstestResult(statistic=np.float64(0.3441782670830466), pvalue=np.float64(6.846446865861517e-80), statistic_location=np.float64(0.09104485282240822), statistic_sign=np.int8(1))
# 2.5 3.5 0.01
# KstestResult(statistic=np.float64(0.31659044532800984), pvalue=np.float64(3.131043842698041e-23), statistic_location=np.float64(0.01943766893428425), statistic_sign=np.int8(1))
# 2.5 4.0 0.01
# KstestResult(statistic=np.float64(0.36080222112085764), pvalue=np.float64(2.3504992077655847e-09), statistic_location=np.float64(0.018318519509317066), statistic_sign=np.int8(1))
# 2.5 3.0 0.01
# KstestResult(statistic=np.float64(0.024302153542659872), pvalue=np.float64(0.7921785194295745), statistic_location=np.float64(-0.3057522229835637), statistic_sign=np.int8(-1))
# 2.5 3.5 0.01
# KstestResult(statistic=np.float64(0.056270717757587206), pvalue=np.float64(0.394538961177925), statistic_location=np.float64(0.3659683323927723), statistic_sign=np.int8(-1))
# 2.5 4.0 0.01
# KstestResult(statistic=np.float64(0.10595101101430215), pvalue=np.float64(0.34172265039661237), statistic_location=np.float64(0.29044136054436975), statistic_sign=np.int8(-1))
# 3.0 3.5 0.01
# KstestResult(statistic=np.float64(0.31698229678784806), pvalue=np.float64(1.972240869316721e-20), statistic_location=np.float64(0.019371645210234552), statistic_sign=np.int8(1))
# 3.0 4.0 0.01
# KstestResult(statistic=np.float64(0.36082602773887856), pvalue=np.float64(5.421712551805233e-09), statistic_location=np.float64(0.017559233852921484), statistic_sign=np.int8(1))
# 3.0 3.5 0.01
# KstestResult(statistic=np.float64(0.05925799573560767), pvalue=np.float64(0.4466199614346965), statistic_location=np.float64(0.13481739081698949), statistic_sign=np.int8(-1))
# 3.0 4.0 0.01
# KstestResult(statistic=np.float64(0.1149090909090909), pvalue=np.float64(0.2839909332689033), statistic_location=np.float64(0.29044136054436975), statistic_sign=np.int8(-1))
# 3.5 4.0 0.01
# KstestResult(statistic=np.float64(0.39439333045471153), pvalue=np.float64(1.7052964717353264e-09), statistic_location=np.float64(0.01643545558862429), statistic_sign=np.int8(1))
# 3.5 4.0 0.01
# KstestResult(statistic=np.float64(0.10132777670091103), pvalue=np.float64(0.5310724409405426), statistic_location=np.float64(-0.2903287058107785), statistic_sign=np.int8(1))
# 2.0 2.5 0.001
# KstestResult(statistic=np.float64(0.2759049783415472), pvalue=np.float64(6.752260273918362e-211), statistic_location=np.float64(-0.1468799670220286), statistic_sign=np.int8(1))
# 2.0 3.0 0.001
# KstestResult(statistic=np.float64(0.2797197977905336), pvalue=np.float64(4.4020492369321035e-64), statistic_location=np.float64(-0.06347730628934053), statistic_sign=np.int8(1))
# 2.0 3.5 0.001
# KstestResult(statistic=np.float64(0.2513607064162857), pvalue=np.float64(7.42041928937735e-17), statistic_location=np.float64(-0.1442971990135324), statistic_sign=np.int8(1))
# 2.0 4.0 0.001
# KstestResult(statistic=np.float64(0.323018227510193), pvalue=np.float64(4.089873327699866e-08), statistic_location=np.float64(-0.058609013465106004), statistic_sign=np.int8(1))
# 2.0 2.5 0.001
# KstestResult(statistic=np.float64(0.019426426678888442), pvalue=np.float64(0.22509812165586018), statistic_location=np.float64(-0.09413025263935061), statistic_sign=np.int8(-1))
# 2.0 3.0 0.001
# KstestResult(statistic=np.float64(0.04158813134876588), pvalue=np.float64(0.08764244519600362), statistic_location=np.float64(-0.33312633747743103), statistic_sign=np.int8(-1))
# 2.0 3.5 0.001
# KstestResult(statistic=np.float64(0.07153267170268851), pvalue=np.float64(0.09593210444241806), statistic_location=np.float64(0.0007860841946412149), statistic_sign=np.int8(-1))
# 2.0 4.0 0.001
# KstestResult(statistic=np.float64(0.08780090407828722), pvalue=np.float64(0.5312156781903575), statistic_location=np.float64(0.1844533376078882), statistic_sign=np.int8(-1))
# 2.5 3.0 0.001
# KstestResult(statistic=np.float64(0.2866362447541351), pvalue=np.float64(1.939369863978573e-60), statistic_location=np.float64(-0.060874816791181126), statistic_sign=np.int8(1))
# 2.5 3.5 0.001
# KstestResult(statistic=np.float64(0.25909763880778375), pvalue=np.float64(2.690371823060855e-17), statistic_location=np.float64(-0.05097625936805688), statistic_sign=np.int8(1))
# 2.5 4.0 0.001
# KstestResult(statistic=np.float64(0.33130296382328905), pvalue=np.float64(2.0912513017782746e-08), statistic_location=np.float64(-0.05853603583427611), statistic_sign=np.int8(1))
# 2.5 3.0 0.001
# KstestResult(statistic=np.float64(0.028711252972596347), pvalue=np.float64(0.5389651210810493), statistic_location=np.float64(-0.3492469963492915), statistic_sign=np.int8(-1))
# 2.5 3.5 0.001
# KstestResult(statistic=np.float64(0.06234897505666914), pvalue=np.float64(0.2218181969335782), statistic_location=np.float64(0.2365847752006688), statistic_sign=np.int8(-1))
# 2.5 4.0 0.001
# KstestResult(statistic=np.float64(0.0783540644993667), pvalue=np.float64(0.6779172230182786), statistic_location=np.float64(0.213250474457151), statistic_sign=np.int8(-1))
# 3.0 3.5 0.001
# KstestResult(statistic=np.float64(0.25731417035764864), pvalue=np.float64(6.305830008475293e-15), statistic_location=np.float64(-0.053801801867927095), statistic_sign=np.int8(1))
# 3.0 4.0 0.001
# KstestResult(statistic=np.float64(0.34208035427547623), pvalue=np.float64(1.3381043197741726e-08), statistic_location=np.float64(-0.3588745883082417), statistic_sign=np.int8(1))
# 3.0 3.5 0.001
# KstestResult(statistic=np.float64(0.0526401344709874), pvalue=np.float64(0.530479165541886), statistic_location=np.float64(0.0007860841946412149), statistic_sign=np.int8(-1))
# 3.0 4.0 0.001
# KstestResult(statistic=np.float64(0.10017151360758696), pvalue=np.float64(0.4055145046666848), statistic_location=np.float64(-0.35883922829062986), statistic_sign=np.int8(1))
# 3.5 4.0 0.001
# KstestResult(statistic=np.float64(0.37082418217547103), pvalue=np.float64(5.962322925240875e-09), statistic_location=np.float64(-0.06893948720167786), statistic_sign=np.int8(1))
# 3.5 4.0 0.001
# KstestResult(statistic=np.float64(0.09760176197079697), pvalue=np.float64(0.5340183479096342), statistic_location=np.float64(-0.3589859050161806), statistic_sign=np.int8(1))

# %%
import numpy as np
import scipy.stats as sp
import matplotlib.pyplot as plt

# Raw columns
x_raw = eqGoodData["TimeDiffNSec"].astype(float).to_numpy()
mag   = eqGoodData["Magnitude"].astype(float).to_numpy()

thresholds = [0.01, 0.001]
mk_vals = [2.0, 2.5, 3.0, 3.5, 4.0]

# Common transform (log first)
x_log = np.log10(x_raw)

def ecdf_line(ax, x, label):
    """Plot an empirical CDF as a step line (what KS uses)."""
    if x.size == 0:
        ax.plot([], [], label=f"{label} (n=0)")
        return
    xs = np.sort(x)
    ys = np.arange(1, x.size + 1) / x.size
    ax.step(xs, ys, where="post", label=f"{label} (n={x.size})")

for t in thresholds:
    t_log = np.log10(t)

    for mk in mk_vals:
        maskA = (mag >= mk) & (x_log > t_log)
        xA = x_log[maskA]

        for ml in mk_vals:
            if mk >= ml:
                continue

            maskB = (mag >= ml) & (x_log > t_log)
            xB = x_log[maskB]

            # --- Guard: if either is empty, skip with a note
            if xA.size == 0 or xB.size == 0:
                print(f"SKIP mk={mk}, ml={ml}, t={t}: sizes {xA.size}, {xB.size}")
                continue

            # Optional: global standardization (same params for both)
            Z = np.concatenate([xA, xB])
            mu, sig = Z.mean(), Z.std(ddof=0) or 1.0
            A = (xA - mu) / sig
            B = (xB - mu) / sig

            # KS on the data you actually plot
            ks = sp.ks_2samp(A, B)
            print(f"mk={mk}, ml={ml}, t={t} → KS={ks.statistic:.4f}, p={ks.pvalue:.3g}")

            # ------- Option 1: cumulative histograms (be sure bins match the STANDARDIZED scale)
            bins = np.linspace(np.min([A.min(), B.min()]),
                               np.max([A.max(), B.max()]),
                               60)



            # ------- Option 2 (recommended): true ECDF lines (no bin issues)
            fig, ax = plt.subplots()
            ecdf_line(ax, A, f"mk ≥ {mk}")
            ecdf_line(ax, B, f"ml ≥ {ml}")
            ax.set_title(f"ECDF (t={t})  KS={ks.statistic:.3f}, p={ks.pvalue:.2g}")
            ax.set_xlabel("Standardized log10(TimeDiffNSec)")
            ax.set_ylabel("F(x)")
            ax.legend()
            plt.show()
# Out:
# mk=2.0, ml=2.5, t=0.01 → KS=0.0276, p=0.00247
# mk=2.0, ml=3.0, t=0.01 → KS=0.0544, p=0.000629
# mk=2.0, ml=3.5, t=0.01 → KS=0.0815, p=0.00718
# mk=2.0, ml=4.0, t=0.01 → KS=0.0894, p=0.281
# mk=2.5, ml=3.0, t=0.01 → KS=0.0336, p=0.139
# mk=2.5, ml=3.5, t=0.01 → KS=0.0581, p=0.13
# mk=2.5, ml=4.0, t=0.01 → KS=0.0722, p=0.548
# mk=3.0, ml=3.5, t=0.01 → KS=0.0421, p=0.58
# mk=3.0, ml=4.0, t=0.01 → KS=0.0697, p=0.628
# mk=3.5, ml=4.0, t=0.01 → KS=0.0716, p=0.69
# mk=2.0, ml=2.5, t=0.001 → KS=0.0276, p=0.00247
# mk=2.0, ml=3.0, t=0.001 → KS=0.0544, p=0.000629
# mk=2.0, ml=3.5, t=0.001 → KS=0.0815, p=0.00718
# mk=2.0, ml=4.0, t=0.001 → KS=0.0894, p=0.281
# mk=2.5, ml=3.0, t=0.001 → KS=0.0336, p=0.139
# mk=2.5, ml=3.5, t=0.001 → KS=0.0581, p=0.13
# mk=2.5, ml=4.0, t=0.001 → KS=0.0722, p=0.548
# mk=3.0, ml=3.5, t=0.001 → KS=0.0421, p=0.58
# mk=3.0, ml=4.0, t=0.001 → KS=0.0697, p=0.628
# mk=3.5, ml=4.0, t=0.001 → KS=0.0716, p=0.69

# %%
#Generated by ChatGPT
import numpy as np
import pandas as pd
import scipy as sp  # so sp.stats.ks_2samp works like in your code

threshold = [0.01, 0.001]
mk_vals   = [2.0, 2.5, 3.0, 3.5, 4.0]
labels    = [f"M ≥ {v:g}" for v in mk_vals]

def rescale_twice(x: pd.Series, t: float) -> pd.Series:
    """Your two-pass: rescale by mean, keep > t, repeat."""
    x = x.dropna().astype(float)
    for _ in (1, 2):
        if len(x) == 0:
            break
        rk = 1.0 / x.mean()
        x = (x * rk)
        x = x.loc[x > t]
    return x

for t in threshold:
    # --- build the rescaled samples for each mk (exactly your logic) ---
    samples = {}
    counts  = []
    for mk in mk_vals:
        x_mk = eqGoodData.loc[eqGoodData["Magnitude"] >= mk, "TimeDiffNSec"]
        x_mk = rescale_twice(x_mk, t)
        samples[mk] = x_mk
        counts.append(len(x_mk))

    # --- make an empty table with strings, then fill it ---
    df = pd.DataFrame("-", index=labels, columns=labels)
    # leftmost N column
    df.insert(0, "N", counts)

    # fill upper (p-values) and lower (KS d) triangles
    for i, mki in enumerate(mk_vals):
        for j, mkj in enumerate(mk_vals):
            if i == j:
                continue
            d, p = sp.stats.ks_2samp(samples[mki], samples[mkj], alternative="two-sided", mode="auto")
            if i < j:   # above diagonal -> p (%)
                df.iat[i, j + 1] = f"{p*100:.1f}%"
            else:       # below diagonal -> d
                df.iat[i, j + 1] = f"{d:.3f}"

    # --- print/output like the paper ---
    print(f"\nTable for m = {t:g}\n")
    print(df.to_string())

    # Optional pretty display in notebooks:
    # display(df.style.set_caption(f"m = {t:g}"))

    # Optional save:
    # df.to_csv(f"ks_table_m_{str(t).replace('.','p')}.csv", index=True)
# Out:
# Table for m = 0.01
#
#              N  M ≥ 2 M ≥ 2.5  M ≥ 3 M ≥ 3.5  M ≥ 4
# M ≥ 2    17951      -   34.5%  36.2%    9.5%  13.2%
# M ≥ 2.5   5389  0.015       -  69.1%   22.8%  15.1%
# M ≥ 3     1350  0.026   0.021      -   35.1%  15.9%
# M ≥ 3.5    390  0.063   0.054  0.053       -  75.0%
# M ≥ 4      109  0.111   0.108  0.110   0.071      -
#
# Table for m = 0.001
#
#              N  M ≥ 2 M ≥ 2.5  M ≥ 3 M ≥ 3.5  M ≥ 4
# M ≥ 2    18711      -    6.7%   6.9%    3.6%  10.8%
# M ≥ 2.5   5669  0.020       -  37.6%   14.8%  13.5%
# M ≥ 3     1443  0.035   0.027      -   36.9%  16.4%
# M ≥ 3.5    422  0.069   0.057  0.050       -  74.3%
# M ≥ 4      115  0.112   0.108  0.107   0.069      -

# %% [markdown]
# your table here

# %% [markdown]
# Did you find any statistical significant differences between the distributions? What does it mean? Is your result identical to Correll's 2018? Why or why not? **Discuss!**

# %% [markdown]
# ### "extra credits"
#
# **How could you _force_ a significant result?**
# Organize your result for different magnitude threshold in a numpy array (it should be a 5x5 array) for both cutoffs (0.01 and 0.001). Each of these arrays should contain the p-value for the pair of distributions i,j in cell \[i\]\[j\] and \[j\]\[i\]. Use ```imshow``` to visualize this 2D data. FIrst visualize the matrix itself as done below.

# %%
# your code here

pl.imshow((ks_001));
pl.axis('off')
cb = pl.colorbar()
cb.ax.set_ylabel(r'$p$-value')
pl.title("KS test results");
#add a caption
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3253189678.py in <cell line: 0>()
#       1 # your code here
#       2
# ----> 3 pl.imshow((ks_001));
#       4 pl.axis('off')
#       5 cb = pl.colorbar()
#
# NameError: name 'ks_001' is not defined

# %% [markdown]
# Now visualize the result as a matrix where the cells are white if the results is not statistically significant and red otherwise.
# After doing it fot the set alpha threshold, lower your alpha threshold so that at least one pair of distribution has a statistically significant difference. **Warning!! this is an _unethical and horrifying practice_! Once you chose your significance threshold you are never allowed to change it! Why? Discuss**

# %% [markdown]
# Redoing it for threshold 0001
